# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # This is the simulated raw file

# %%
vs_raw=pd.read_csv(r"C:\Users\PC\Downloads\Vs_raw (2).csv")
vs_raw
# Out:
#             study_id  site_id  subj_id  visit    HR  SYS_BP  DIA_BP  TEMP  \
# 0      CPU-Methyl125      104   104001      1  75.0   115.0    79.0  36.4
# 1      CPU-Methyl125      104   104001      2  69.0   117.0    81.0  37.3
# 2      CPU-Methyl125      104   104001      3  76.0   107.0    72.0  36.8
# 3      CPU-Methyl125      104   104001      4  85.0   134.0   109.0  36.4
# 4      CPU-Methyl125      104   104001      5  68.0   117.0    75.0  37.0
# ...              ...      ...      ...    ...   ...     ...     ...   ...
# 21666  CPU-Methyl125      102  1021500     19  76.0   119.0    93.0  36.9
# 21667  CPU-Methyl125      102  1021500     20  68.0   141.0    85.0  36.8
# 21668  CPU-Methyl125      102  1021500     21  69.0   124.0    82.0  35.9
# 21669  CPU-Methyl125      102  1021500     22  64.0   122.0    84.0  36.4
# 21670  CPU-Methyl125      102  1021500     23  75.0   130.0    93.0  36.9
#
#        RESP  Pulse_rate   WGT    HGT        vital_group  planned_timepoint  \
# ...

# %% [markdown]
# # The Output

# %%
vs_output=pd.read_csv(r"C:\Users\PC\Documents\Python Scripts\Files\vs_output.csv")
vs_output
# Out:
#               STUDYID DOMAIN                   USUBJID            VSGRPID  \
# 0       CPU-Methyl125     VS  CPU-Methyl125-101-101002  CPUMethylGrp00033
# 1       CPU-Methyl125     VS  CPU-Methyl125-101-101002  CPUMethylGrp00033
# 2       CPU-Methyl125     VS  CPU-Methyl125-101-101002  CPUMethylGrp00033
# 3       CPU-Methyl125     VS  CPU-Methyl125-101-101002  CPUMethylGrp00033
# 4       CPU-Methyl125     VS  CPU-Methyl125-101-101002  CPUMethylGrp00033
# ...               ...    ...                       ...                ...
# 193951  CPU-Methyl125     VS  CPU-Methyl125-104-104998  CPUMethylGrp14556
# 193952  CPU-Methyl125     VS  CPU-Methyl125-104-104998  CPUMethylGrp14556
# 193953  CPU-Methyl125     VS  CPU-Methyl125-104-104998  CPUMethylGrp14556
# 193954  CPU-Methyl125     VS  CPU-Methyl125-104-104998  CPUMethylGrp14556
# 193955  CPU-Methyl125     VS  CPU-Methyl125-104-104998  CPUMethylGrp14556
#
#                           VSSPID VSTESTCD                    VSTEST  \
# ...
